# %% [markdown]
# <a href="https://colab.research.google.com/github/ap281103-ops/Pemograman-Dasar-Tugas-1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "Aidil"
umur = 23
hobi = "Futsal"
kuliah = "Polibatam"
kelas = "Malam A"
jurusan = "RPE"
semester = 3
matakuliah = "Pemerograman Dasar"
status_lulus = False


print (nama)
print (umur)
print (hobi)
print (kuliah)
print (kelas)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# Aidil
# 23
# Futsal
# Polibatam
# Malam A
# RPE
# 3
# Pemerograman Dasar
# False
